# %% [markdown]
# ## 필요 라이브러리

# %%
import os
import pandas as pd
pd.set_option('display.max_colwidth', None)
import matplotlib.pyplot as plt
import re

from pyspark.sql.functions import col, to_timestamp
import pymysql
import mysql.connector
import pandas as pd
from kiwi import kiwi
from kiwipiepy import Kiwi
import os
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType
from konlpy.tag import Okt
from collections import Counter
from wordcloud import WordCloud
from konlpy.tag import Kkma
from umap.umap_ import UMAP
import hdbscan
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from pyspark.sql.functions import col, to_timestamp
from transformers import AutoTokenizer, AutoModel, AutoModelForSequenceClassification, pipeline
import torch
import emoji
from soynlp.normalizer import repeat_normalize

# %% [markdown]
# ## 환경변수 설정

# %%
os.environ['PYSPARK_PYTHON'] = '/home/ubuntu/anaconda3/envs/Project/bin/python'
os.environ['PYSPARK_DRIVER_PYTHON'] = '/home/ubuntu/anaconda3/envs/Project/bin/python'
os.environ['PYSPARK_SUBMIT_ARGS'] = '--jars /usr/local/lib/mysql-connector-java-5.1.49-bin.jar pyspark-shell'

# %% [markdown]
# ## MySQL에서 테이블 로드

# %% [markdown]
# ### MySQL 서버 접속 정보

# %%
host_ip = "15.168.221.131"  
DATABASE = "SNS_DB"
user_id = "lab13"
user_password = "lab13"
mysql_url = f"jdbc:mysql://{host_ip}:3306/{DATABASE}"

# %%
connection = mysql.connector.connect(
    host='localhost',
    user='lab13',
    password='lab13',
    database='SNS_DB',
    charset='utf8mb4'
)

cursor = connection.cursor()
cursor.execute("SHOW TABLES;")  
for table in cursor.fetchall():
    print(table[0])
# Out:
# tbCrawled_Danawa
# tbCrawled_Youtube

# %%
table_name = "tbCrawled_Youtube"
cursor.execute(f"SELECT * FROM {table_name} LIMIT 10;") 
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, 'sDWeyVdXQwY', '새로운 삼성 갤럭시 S24/S24+/S24 울트라 첫 인상! 아이폰같은데 예뻐졌습니다.', datetime.datetime(2024, 1, 17, 23, 30, 17), 'ITSub잇섭', '플러스 사용중인데 대만족 진짜', 0, datetime.datetime(2024, 2, 4, 6, 17, 55), datetime.datetime(2025, 2, 20, 13, 10))
# (2, 'sDWeyVdXQwY', '새로운 삼성 갤럭시 S24/S24+/S24 울트라 첫 인상! 아이폰같은데 예뻐졌습니다.', datetime.datetime(2024, 1, 17, 23, 30, 17), 'ITSub잇섭', '역시 삼성도살자', 0, datetime.datetime(2024, 1, 19, 15, 30, 4), datetime.datetime(2025, 2, 20, 13, 10))
# (3, 'sDWeyVdXQwY', '새로운 삼성 갤럭시 S24/S24+/S24 울트라 첫 인상! 아이폰같은데 예뻐졌습니다.', datetime.datetime(2024, 1, 17, 23, 30, 17), 'ITSub잇섭', '급 나누기 대박!\n일반 모델 엑시노스\n플 울 스냅 젠3\n램 \n카메라 \n배터리 용량\n소재\n무충도 일반은 15와트가 아닐까 싶네요\n다행인건 울트라 디스플레이가 플랫이라 괜찮아 보이네요\n챔버가 전작보다 더 커졌다는데\n발열이 얼마나 날지 궁금해지네요ㅎ', 3, datetime.datetime(2024, 1, 18, 7, 30, 46), datetime.datetime(2025, 2, 20, 13, 10))
# (4, 'sDWeyVdXQwY', '새로운 삼성 갤럭시 S24/S24+/S24 울트라 첫 인상! 아이폰같은데 예뻐졌습니다.', datetime.datetime(2024, 1, 17, 23, 30, 17), 'ITSub잇섭', '아직도 램 8기가야? S20이 12기간데', 0, datetime.datetime(2024, 1, 18, 7, 12, 14), datetime.datetime(2025, 2, 20, 13, 10))
# (5, 'sDWeyVdXQwY', '새로운 삼성 갤럭시 S24/S24+/S24 울트라 첫 인상! 아이폰같은데 예뻐졌습니다.', datetime.datetime(2024, 1, 17, 23, 30, 17), 'ITSub잇섭', '애플이 왜 중국에서 할인해줄까? 갤럭시가 왜 중국에만 좋은걸 해줄까? 그만큼 중국먹는 기업이 승자니깐 중국한테 좋은거 다해주는거임. 그리고 자국민이란 새끼들이 나라먹여살려주는 기업 개무시하고 갤래기라고 욕만하는데 누가 좋다고 기능 업그레이드 해줌 ㅋㅋㅋㅋ 그동안 8램쓰면서 불편한거 하나도 없었는데 도대체 뭘하길래 12램에 집착하는지 이해안됨. 그렇게 램이 중요하면 가격 얼마 차이안나는 플러스모델 사면되겠네 ㅋㅋㅋ', 0, datetime.datetime(2024, 1, 18, 5, 24, 30), datetime.datetime(2025, 2, 20, 13, 10))
# (6, 'sDWeyVdXQwY', '새로운 삼성 갤럭시 S24/S24+/S24 울트라 첫 인상! 아이폰같은데 예뻐졌습니다.', datetime.datetime(2024, 1, 17, 23, 30, 17), 'ITSub잇섭', '램 언제늘릴려나 아니 s모델이 플래그쉽모델인데 램 다운하고 아직도 저렇게 낸다는게 참..', 0, datetime.datetime(2024, 1, 18, 2, 12, 33), datetime.datetime(2025, 2, 20, 13, 10))
# (7, 'sDWeyVdXQwY', '새로운 삼성 갤럭시 S24/S24+/S24 울트라 첫 인상! 아이폰같은데 예뻐졌습니다.', datetime.datetime(2024, 1, 17, 23, 30, 17), 'ITSub잇섭', '액시노스2400… 걱정반 기대반…', 0, datetime.datetime(2024, 1, 18, 1, 54, 35), datetime.datetime(2025, 2, 20, 13, 10))
# (8, 'sDWeyVdXQwY', '새로운 삼성 갤럭시 S24/S24+/S24 울트라 첫 인상! 아이폰같은데 예뻐졌습니다.', datetime.datetime(2024, 1, 17, 23, 30, 17), 'ITSub잇섭', '오프닝 머야 ㅋ', 0, datetime.datetime(2024, 1, 18, 0, 16, 9), datetime.datetime(2025, 2, 20, 13, 10))
# (9, 'sDWeyVdXQwY', '새로운 삼성 갤럭시 S24/S24+/S24 울트라 첫 인상! 아이폰같은데 예뻐졌습니다.', datetime.datetime(2024, 1, 17, 23, 30, 17), 'ITSub잇섭', '출근할 때 잇섭이라니.. 궈하네용', 0, datetime.datetime(2024, 1, 17, 23, 59, 5), datetime.datetime(2025, 2, 20, 13, 10))
# (10, 'sDWeyVdXQwY', '새로운 삼성 갤럭시 S24/S24+/S24 울트라 첫 인상! 아이폰같은데 예뻐졌습니다.', datetime.datetime(2024, 1, 17, 23, 30, 17), 'ITSub잇섭', '14분 타임포인트에 s24 & s24 뭔가 했는데 +가 빠진거였넼ㅋㅋㅋㅋ', 0, datetime.datetime(2024, 1, 17, 23, 39, 45), datetime.datetime(2025, 2, 20, 13, 10))

# %%
cursor.execute(f"SELECT COUNT(*) FROM {table_name};")
count = cursor.fetchone()[0]
count
# Out:
# 69950

# %% [markdown]
# ## 판다스 df로 변환

# %%
cursor.execute(f"SELECT * FROM {table_name};")
data = cursor.fetchall()
df = pd.DataFrame(data, columns=['index', 'video_id', 'title', 'publish_date', 'channel_name', 'comment', 'like_count', 'comment_publish_date', 'load_date'])

df = df.drop(columns=[df.columns[0]])
df.head(10)
# Out:
#       video_id                                             title  \
# 0  sDWeyVdXQwY  새로운 삼성 갤럭시 S24/S24+/S24 울트라 첫 인상! 아이폰같은데 예뻐졌습니다.
# 1  sDWeyVdXQwY  새로운 삼성 갤럭시 S24/S24+/S24 울트라 첫 인상! 아이폰같은데 예뻐졌습니다.
# 2  sDWeyVdXQwY  새로운 삼성 갤럭시 S24/S24+/S24 울트라 첫 인상! 아이폰같은데 예뻐졌습니다.
# 3  sDWeyVdXQwY  새로운 삼성 갤럭시 S24/S24+/S24 울트라 첫 인상! 아이폰같은데 예뻐졌습니다.
# 4  sDWeyVdXQwY  새로운 삼성 갤럭시 S24/S24+/S24 울트라 첫 인상! 아이폰같은데 예뻐졌습니다.
# 5  sDWeyVdXQwY  새로운 삼성 갤럭시 S24/S24+/S24 울트라 첫 인상! 아이폰같은데 예뻐졌습니다.
# 6  sDWeyVdXQwY  새로운 삼성 갤럭시 S24/S24+/S24 울트라 첫 인상! 아이폰같은데 예뻐졌습니다.
# 7  sDWeyVdXQwY  새로운 삼성 갤럭시 S24/S24+/S24 울트라 첫 인상! 아이폰같은데 예뻐졌습니다.
# 8  sDWeyVdXQwY  새로운 삼성 갤럭시 S24/S24+/S24 울트라 첫 인상! 아이폰같은데 예뻐졌습니다.
# 9  sDWeyVdXQwY  새로운 삼성 갤럭시 S24/S24+/S24 울트라 첫 인상! 아이폰같은데 예뻐졌습니다.
#
#          publish_date channel_name  \
# 0 2024-01-17 23:30:17      ITSub잇섭
# 1 2024-01-17 23:30:17      ITSub잇섭
# 2 2024-01-17 23:30:17      ITSub잇섭
# 3 2024-01-17 23:30:17      ITSub잇섭
# 4 2024-01-17 23:30:17      ITSub잇섭
# 5 2024-01-17 23:30:17      ITSub잇섭
# 6 2024-01-17 23:30:17      ITSub잇섭
# 7 2024-01-17 23:30:17      ITSub잇섭
# 8 2024-01-17 23:30:17      ITSub잇섭
# 9 2024-01-17 23:30:17      ITSub잇섭
#
#                                                                                                                                                                                                                                     comment  \
# 0                                                                                                                                                                                                                          플러스 사용중인데 대만족 진짜
# 1                                                                                                                                                                                                                                  역시 삼성도살자
# 2                                                                                        급 나누기 대박!\n일반 모델 엑시노스\n플 울 스냅 젠3\n램 \n카메라 \n배터리 용량\n소재\n무충도 일반은 15와트가 아닐까 싶네요\n다행인건 울트라 디스플레이가 플랫이라 괜찮아 보이네요\n챔버가 전작보다 더 커졌다는데\n발열이 얼마나 날지 궁금해지네요ㅎ
# 3                                                                                                                                                                                                                    아직도 램 8기가야? S20이 12기간데
# 4  애플이 왜 중국에서 할인해줄까? 갤럭시가 왜 중국에만 좋은걸 해줄까? 그만큼 중국먹는 기업이 승자니깐 중국한테 좋은거 다해주는거임. 그리고 자국민이란 새끼들이 나라먹여살려주는 기업 개무시하고 갤래기라고 욕만하는데 누가 좋다고 기능 업그레이드 해줌 ㅋㅋㅋㅋ 그동안 8램쓰면서 불편한거 하나도 없었는데 도대체 뭘하길래 12램에 집착하는지 이해안됨. 그렇게 램이 중요하면 가격 얼마 차이안나는 플러스모델 사면되겠네 ㅋㅋㅋ
# 5                                                                                                                                                                                         램 언제늘릴려나 아니 s모델이 플래그쉽모델인데 램 다운하고 아직도 저렇게 낸다는게 참..
# 6                                                                                                                                                                                                                        액시노스2400… 걱정반 기대반…
# 7                                                                                                                                                                                                                                  오프닝 머야 ㅋ
# 8                                                                                                                                                                                                                        출근할 때 잇섭이라니.. 궈하네용
# 9                                                                                                                                                                                                  14분 타임포인트에 s24 & s24 뭔가 했는데 +가 빠진거였넼ㅋㅋㅋㅋ
#
#    like_count comment_publish_date           load_date
# 0           0  2024-02-04 06:17:55 2025-02-20 13:10:00
# 1           0  2024-01-19 15:30:04 2025-02-20 13:10:00
# 2           3  2024-01-18 07:30:46 2025-02-20 13:10:00
# 3           0  2024-01-18 07:12:14 2025-02-20 13:10:00
# 4           0  2024-01-18 05:24:30 2025-02-20 13:10:00
# 5           0  2024-01-18 02:12:33 2025-02-20 13:10:00
# 6           0  2024-01-18 01:54:35 2025-02-20 13:10:00
# 7           0  2024-01-18 00:16:09 2025-02-20 13:10:00
# 8           0  2024-01-17 23:59:05 2025-02-20 13:10:00
# 9           0  2024-01-17 23:39:45 2025-02-20 13:10:00

# %%
df.shape
# Out:
# (69950, 8)

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (73174, 8)

# %%
df_tmp = df.copy()

# %%
df_tmp.video_id.nunique()
# Out:
# 129

# %% [markdown]
# ## 브랜드 분류

# %%
def classify_brand(comment):
    apple_keywords = ["애플", "아이폰", "프로", "미니", "맥스", "플러스", "프맥"]
    samsung_keywords = ["삼성", "갤럭시", "노트", "울트라", "폴드", "플립"]
    
    apple = any(keyword in comment for keyword in apple_keywords)
    samsung = any(keyword in comment for keyword in samsung_keywords)

    if apple and samsung:
        return 'both'
    elif apple:
        return 'apple'
    elif samsung:
        return 'samsung'
    else:
        return 'neither'

# 브랜드별로 댓글 나누기
df_tmp['brand'] = df_tmp['comment'].apply(classify_brand)
apple_df = df_tmp[df_tmp['brand'] == 'apple']
samsung_df = df_tmp[df_tmp['brand'] == 'samsung']
both_df = df_tmp[df_tmp['brand'] == 'both']
neither_df = df_tmp[df_tmp['brand'] == 'neither']

apple_df.shape, samsung_df.shape, both_df.shape, neither_df.shape
# Out:
# ((12361, 9), (11176, 9), (4764, 9), (44873, 9))

# %%
total_comments = df_tmp.shape[0]

apple_count = apple_df.shape[0]
samsung_count = samsung_df.shape[0]
both_count = both_df.shape[0]
neither_count = neither_df.shape[0]

apple_ratio = apple_count / total_comments * 100
samsung_ratio = samsung_count / total_comments * 100
both_ratio = both_count / total_comments * 100
neither_ratio = neither_count / total_comments * 100

print(f"Apple 브랜드 댓글 비율: {apple_ratio:.2f}%")
print(f"Samsung 브랜드 댓글 비율: {samsung_ratio:.2f}%")
print(f"Both 브랜드 댓글 비율: {both_ratio:.2f}%")
print(f"Neither 브랜드 댓글 비율: {neither_ratio:.2f}%")
# Out:
# Apple 브랜드 댓글 비율: 16.89%
# Samsung 브랜드 댓글 비율: 15.27%
# Both 브랜드 댓글 비율: 6.51%
# Neither 브랜드 댓글 비율: 61.32%

# %%
## both_df, neither_df 처리방안!!!
both_df.comment.head(30)
# Out:
# 4                                                                                        애플이 왜 중국에서 할인해줄까? 갤럭시가 왜 중국에만 좋은걸 해줄까? 그만큼 중국먹는 기업이 승자니깐 중국한테 좋은거 다해주는거임. 그리고 자국민이란 새끼들이 나라먹여살려주는 기업 개무시하고 갤래기라고 욕만하는데 누가 좋다고 기능 업그레이드 해줌 ㅋㅋㅋㅋ 그동안 8램쓰면서 불편한거 하나도 없었는데 도대체 뭘하길래 12램에 집착하는지 이해안됨. 그렇게 램이 중요하면 가격 얼마 차이안나는 플러스모델 사면되겠네 ㅋㅋㅋ
# 10                                                                                                                                                                                                              남이 만든 고성능 최신 칩, 메모리  사다 넣고 AI 기술 좀 발전된거 넣은거 말고 삼성이 한게 뭐있나 싶다.\n전혀 새로울게 없는, 다음 애플 신제품에 피떡되게 얻어 맞을 것 같은 불길한 예감이 솔솔~
# 42                                                                                   삼성이 애플대비 마케팅,광고력이 많이 부족하긴한듯\nS24울트라 디스플레이 저반사율 많이 상향된거랑 글래스 흠집 거의 안나는거 몰랐었네\n\n별 시덥지 않은거도 과장광고 뒤지게 하는 애플 아이폰이 저반사, 흠집 강화였으면 역대급! 최고의! 두둥! 하면서 아이폰 이 온갖 시련과 고난 역경이 휩쓸어가도 전면 글라스가 흠집에 아무렇지 않다는 느낌으로 광고영상 연출했을텐데\n\n삼성은 자신의 강점을 좀 더 부각 시킬필요가 있음
# 50                                                                                                                                                                                                                                                                       북미버전은 기본형과 플러스모델도 12기가 램에 울트라와 동일한 스냅드래곤인데... 국내버전은 아쉽네요
# 51                                                                                                                                                                                                                                                                      아이폰에서 갤럭시로 갈아탔다고요? 정말? 아직도 메인을 아이폰을 들고 다니잖아요.... 왜 거짓말해요?
# 67                                                                                                                                                                                                                                                                                         삼성도 확실히 카메라 좋다니까? 이제는 아이폰과 갤럭시는 취향 차이임
# 101                                                                                                                                                                                                          아이폰 유저인데 갤럭시 잘 나온거처럼 보이네요. 직장인이라 통화 녹음 땜에 항상 갤럭시 사고 싶지만 개인적으로 화면 안에  디자인이 항상 아쉬움ㅠ 핸드폰 디자인은 이정도면 이쁜거 같은데... 무튼 그렇다구요.
# 103                                                                                                                                                                                                                                                                                           항상 ap우위였던 애플이 이젠 삼성한테 뒤쳐지니까 어색하네 ㅋㅋ
# 130                                                                                                                                                                                                                                   업무용으로 울라리랑 일상용 아이폰 13프로같이 사용중인데 스피커는 아이폰이 좋더라고요..\n그리고 울라리 무게가 부담돼서 다음에 갤럭시는 일반이나 플러스 살까합니다
# 136                                                                                                                                                                     겔럭시 24울트라에서 ai 활성화 할때 베떠리가 반 이상 줄어요 저만 그런가요 저는 삼성에 이 문제로 as를 요청 하엿는데 삼성은 문제점을 발견을 못하였다 하네요 저만이 않이라 삼성 24울트라를 ai 활성화 상태 유지시 베터리 50프로 정도 줄은 경험 잇으면 제발 알려주세요
# 153                                                                                                                                                                                                                                                                                      저도 사용하면서 울트라 미니 나왔으면 하는 생각 많이 하게되더라구요..😢
# 160                                                                                                                                                                                                                                                                                       아이폰 프로 200만원이 넘던데 그걸 왜삼 차라리 울트라나 폴드를 사지
# 161                                                                                                                                                                                                                                                                                              15는 기본이고 프로 울트라급이면\n갤럭시 처바른지 오래임
# 173                              샤오미....미국에 진출하면 바로 애플 특허 침해 소송 걸 듯 한데요...\n참고로 삼성 잠금화면 밀어서 잠금해제 이걸로 특허 침해 소송 당해서\nUI바꿨잖아요...대충적으로 보니까 일부 애플에서 디자인 특허 침해소송 걸릴만한\nUI가 많이 보이는데요.......참고로 애플 UI특허도 엄청 많이 해놓은 상태라...\n애플에서 여차하면 특허소송 걸 듯...중국 내수용이면 특허 소송 걸어봐야 소용없으니\n가만히 있는 듯 하고 구미쪽에 만약 진출해서 일정 부분의 점유율 나오는 순간 특허 소송 들어갈 듯 합니다만...
# 186                                                                                                                                                                                                                     동일 성능에 저게 삼성이나 애플이면 걍 200만원 넘음..자국 이미지가 이렇게 중요함.. 중국은 스맛폰 회사가 많아서 신제품 출시되면 경쟁이 엄청남.. 삼성은 홀로 독점.. 자꾸 따라잡힌다
# 196                                                                                                                                                                                                                                                                                           아이폰 발열 너무 심해서 다음부턴 플립6로 갈아타야겠다 진짜..
# 209                                                                                                                                                                                                                                                            오늘 삼성스토어 갔는데 어제 8시쯤 완판했다고 없다고 하더라구요 ㅠㅠ 온누리 200만원 충전해서 오프로 사야하는데 ㅠㅠ
# 218                                                                                                                                                                                                                                                                             이번에 폰 바꿀건데 전체적으로 하면 \nS24 플러스가 좋나요? S24 울트라가 좋나요?
# 225                                                                                                                                                                                                                                                                                무게는 금방 익숙해질거임 오히려 울트라 쓰다가 플러스 쓰면 작아서 답답해서 못쓸거임
# 232                                                                                                                                                                                                                   전 아이폰만 10년정도 쓰다 이번 갤럭시24 일반 이마트에서 보고 너무 가볍고 디자인도 이쁘고 좋아서 바꿨는데 진짜 만족합니다.아이폰 보다 모든점에서 좋은데 배터리는 역시 아이폰이 오래가네요.
# 247                                                                                                                                                                     S21+ 쓰다가 홍미노트11프로 쓰다가 Z플립4 쓰는데 S시리즈도 점점 예뻐지네요 물빠진 색감은 저는 오히려 호입니다. 색온도 6500K인게 좋아서 자연스러운 화면으로 쓰기에 \n그런데 솔직히 S 플러스가 이쁜건 맞는데 플립이 더 이쁘긴 하더라구요 ㅎㅎ 플립 6 기대합니다.
# 255                                                                                                                                                                                                                                                                                     갤럭시는 A시리즈 S시리즈 모두 똑같이 생겨서 희소성이 없음 아이폰이 최고
# 263                                                                                                                                                                                                                                                               아잇 울트라 사려던 마음 잇섭님이 플러스로 꺾어주셨는데... 울트라를 사용중이셔서 플러스 후기를 못보네요...ㅜㅜ
# 267                                                                                                                                                                                                                                                                                                 진짜 FE같은것들 그만 내고 미니울트라 나오면 좋겠다
# 295    S24울트라 빨기만하는 유투버 영업사원이랑은 격이다른 잇섭님 유투브채널 \n이번에 엑시노스도그렇고 칼을갈았니하는놈들 대가리박아라. \n디자인이  아재폰 그냥40대  50대가 수첩형케이스에넣어가. 펼지면서 다시보지도않을 풍경 사진찍으려고 온갖추태를부리는 모습이 상상되는건 디자인탓인가 \n인간적으로 사이즈라도2가지 내어놓는성의라도...사이즈가 딱s24보다 조금 큰수준이면딱일것을  애플처럼 맥스든 프로처럼 ...폴드는 이름만 4. 5 바뀌고 그나마혁신인건 플립이다 \nLg가 접고나서 너무 막나간다는생각이든다 이래서 경쟁자가 다수있어야돼 부활하라 스카이 모토로라여
# 332                                                                                                                                                                                                         혹시 나중에 가능하다면\n스드 들어간 기본이랑 플러스랑\n엑시노스 들어간 기본 플러스도 차이가 얼마나 있을지 보고싶어요.\n\n울트라는 아무래도 더 큰 방열판이라는 이점이 있기는 하니깐 완벽한 비교는 아니니깐요
# 336                                                                                                                                                                                                                                  저는 ai기능 별로 관심 없고요. 카메라는 좋았으면 좋겠는데 게임은 안합니다. 참 소비자 마음 몰라주네 싶어요. 근데 디자인이 울트라가 너무 못생겨서 플러스 했습니다
# 340                                                                                                                                                                                                   24울트라 23울트라와 다른건없다고 하지만 24울써보시면 지문인식 부터 접속하는 모든게 빠른걸 넘어서 너무빨라요 써보시면 알아요\n배터리 오전9에 100프로  저녁9시에 40프로 남네요  하루종일 폰 쓴거같은데 엄청나네요
# 360                                                                                                                                                                                                                                                                                                  그래도 고민이다...아이폰16이냐 갤럭시24냐...
# 374                                                                                                                                                                                                                                                                                  다시 갤럭시로 돌아가고시픔..아이폰 쓰는 중인데.. 다음 폰은 무조건 갤럭시다😂
# Name: comment, dtype: object

# %%
neither_df.comment.head(30)
# Out:
# 3                                                                                        아직도 램 8기가야? S20이 12기간데
# 5                                                             램 언제늘릴려나 아니 s모델이 플래그쉽모델인데 램 다운하고 아직도 저렇게 낸다는게 참..
# 6                                                                                            액시노스2400… 걱정반 기대반…
# 7                                                                                                      오프닝 머야 ㅋ
# 8                                                                                            출근할 때 잇섭이라니.. 궈하네용
# 9                                                                      14분 타임포인트에 s24 & s24 뭔가 했는데 +가 빠진거였넼ㅋㅋㅋㅋ
# 11                                                            10:51 실리콘 카바이드 ㄴㄴ 실리콘-카본 ㅇㅋ. 실리콘+카본 복합체이지 합금이 아님.
# 12                                                                   잇섭님 영상과 조금 동떨어진 얘기지만 S23 시리즈 현 시점에도 쓸만한가요?
# 13    미국, 유럽에선 엄청 까이던데 ㅋㅋㅋ\n중국폰 보다 50만원 비싼데 배터리 두껍고 용량도 작고\ns20부터 여전히 램 12gb 유지하고 있다며..\n하지만 한국은 전모델 스냅만으로도 극-락
# 16                                                                                                  인기 급상승 1위네요
# 17                                                                                       8:43 저 점수는 어떤 걸 뜻하나요??
# 23                                             09:24 10:59 솔직한 잇섭님 리뷰 ㅋㅋ 이래서 it는 잇섭님꺼만 봄\n17:29 저만 그런게 아니었네요 ㅠㅠ
# 24                                                                              벨벳쓰다가 24플넘어왓는데 존나좋넹ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 25                                                                                                 울라리 ?? 구독취소함
# 26                                                                                       3:54 새건데 벌써 한번 떨어뜨리셨군여
# 27                                         홈페에 폰 하이라이트 소개하는데  엑시노스 단어도 안보이네요.  자신이 없어서 인지  아님 서프라이즈라도 줄려고 하는건지.
# 28                                                                                                         8:59
# 30                                                                                   별생각 없었는데 5배 광학줌 실용성 개좋음...
# 33                                                                                                  클리어뜻을 모르나??
# 34                                                                                                      구독취소 완료
# 35                       디지털 줌이라면 초점거리는 줌하기전 수치로 표시하는게 맞는것 같네요~ 어차피 그화각으로 찍어서 크롭한것에 불과하니까 화질측면에서 광학줌과 차이가 있을테구요
# 36                                                                                                  베가아이언 느낌 킁킁
# 37                                                                             써보니 70세 나는 편해 무얼 어떻게 해야 고민 없어져 ㅋ
# 38                                                                                    실시간 통역 좋은거 같은데 추후에 유료화라니😩
# 43                                                                                           전체적으로 색상이 너무 아재스럽다
# 44                                                                     이슈에 대한 생각이 없어 조금 아쉽네요.. 22못지않게 문제 많던데...
# 47                                                                                            손까지셨네 올리브링에 베이셨나?
# 48                                                                                     손딸방이 많이 좋아졌네! 좀 더 부드러워졌어
# 49                                                                    먼가 아마추어들이 만든 것 중에 최고인 것 같은 좀 부족한 휴대폰이네...
# 52                                                                                         챕터에 S24 & S24로 되어있아용
# Name: comment, dtype: object

# %% [markdown]
# ## 데이터 전처리

# %% [markdown]
# ### 불용어 처리
# - https://raw.githubusercontent.com/yoonkt200/FastCampusDataset/master/korean_stopwords.txt

# %%
stopwords = []
stopwords = pd.read_csv("https://raw.githubusercontent.com/yoonkt200/FastCampusDataset/master/korean_stopwords.txt").values.tolist()

stopwords += [
              "일반", "사용", "고민", "워치", "생각", "에어팟", "차이", "만원", "시리즈", "하나", "사고",
              "부터", "쓰기", "시작", "진짜", "그냥", "너무", "인데", "입니다", "다시", "역시",
              "하는", "많이", "보다", "해서", "지금", "으로", "에서", "하고", "언제", "처음",
              "까지", "정도", "이제", "때문", "했는데", "하면", "근데",
              "보고", "쓰고", "이나", "합니다", "호구", "이번", ]

# %% [markdown]
# ### 띄어쓰기 보정
# - pykospacing (tensorflow 버전 이슈)
# - kiwi (쏙도 느림)
#
# ### 형태소 추출
# - Okt

# %%
def extract_noun(comment):
    # 띄어쓰기 보정
    okt = Okt()
    comment = ' '.join(okt.morphs(comment))

    # 이모지 제거
    comment = re.sub(r'[^\w\s,]', '', comment)

    # 2개 이상의 반복된 문자 제거 (초성만 있는 단어들 처리)
    comment = re.sub(r'[ㄱ-ㅎ]{2,}', '', comment)

    # 한 글자 단어 제거
    comment = re.sub(r'\b\w{1}\b', '', comment)

    # 명사만 추출
    nouns = okt.nouns(comment)

    # 불용어 제거
    nouns = [noun for noun in nouns if noun not in stopwords]

    return ' '.join(nouns)

def cleaning_text(comment):
    # 띄어쓰기 보정
    okt = Okt()
    comment = ' '.join(okt.morphs(comment))

    # 이모지 제거
    comment = re.sub(r'[^\w\s,]', '', comment)

    # 2개 이상의 반복된 문자 제거 (초성만 있는 단어들 처리)
    comment = re.sub(r'[ㄱ-ㅎ]{2,}', '', comment)

    # 한 글자 단어 제거
    comment = re.sub(r'\b\w{1}\b', '', comment)
    return comment

# %%
apple_df['cleaned_comment'] = apple_df['comment'].apply(cleaning_text)
apple_df['cleaned_comment'].head()
# Out:
# 7                                                                                                                                                                                                                       13 pro 에서 넘어갈만  가요 아이폰  부터 지금 까지 애플  써서 겔럭시  처음  보는데
# 20    Ai 업댓  긍정    하나  접근성  쉬워졌다는 겁니다  가끔 이미지 검색 하고 싶을  이미지  저장  거나 스샷  따로 떠서 그걸  저장 해서 구글  들어가서 이미지 검색 으로 들어가서  폴더   이미지  찾아서 확인 누르고 검색    그냥  버튼 하나 누르고 스윽   어서 검색 결과 확인     같은 프로세스  견디기 힘들어서 컴퓨터 로는   써도  에선 거의  썼는데 요즘    쓰고 있습니다    하나  해도   크게 의미 있는 기능 업댓 이라고 생각 해요
# 69                                                                                                                                                                                                                                                         확실히 아이폰  이쁘긴 이쁘네요
# 71                                                                                                                                                                                                                                             두목  아직 아이폰 15 시리즈 리뷰  올라왔습니다
# 74                                                                                                                                                                                                                                  반사 애플   정도  만들었어  호들갑 떨면서 홍보  인용 으로 쓸꺼야
# Name: cleaned_comment, dtype: object

# %%
both_df['cleaned_comment'] = both_df['comment'].apply(cleaning_text)

# %%
both_df['cleaned_comment'].head()
# Out:
# 4                 애플   중국 에서 할인 해줄까  갤럭시   중국 에만 좋은걸 해줄까  그만큼 중국 먹는 기업  승자 니깐 중국 한테 좋은  다해 주는거   그리고  국민 이란 새끼   나라 먹여 살려주는 기업 개무시 하고 갤래  라고   하는데 누가 좋다고 기능 업그레이드 해줌  그동안   쓰면서 불편한거 하나  없었는데 도대체  하길래 12   집착 하는지 이해 안됨  그렇게   중요하면 가격 얼마 차이안나는 플러스 모델 사면되 겠네
# 10                                                                                                                                               만든 고성능 최신  , 메모리 사다 넣고 AI 기술  발전 된거 넣은거 말고 삼성     있나 싶다  \n 전혀 새로울게 없는 , 다음 애플 신제품  피떡 되게 얻어 맞을  같은 불길한 예감  솔솔
# 42    삼성  애플 대비 마케팅 , 광고   많이 부족하긴   \n  24 울트라 디스플레이  반사율 많이 상향 된거  글래스 흠집 거의 안나는거 몰랐었네 \n\n   덥지 않은거도 과장 광고 뒤지게 하는 애플 아이폰   반사 , 흠집 강화 였으면 역대   최고   두둥  하면서 아이폰  온갖 시련  고난 역경  휩쓸어가도 전면 글라스  흠집  아무렇지 않다는 느낌 으로 광고 영상 연출 했을텐데 \n\n 삼성  자신  강점    부각 시킬 필요  있음
# 50                                                                                                                                                                                                     북미 버전  기본   플러스 모델  12     울트라  동일한 스냅드래곤 인데  국내 버전  아쉽네요
# 51                                                                                                                                                                                                       아이폰 에서 갤럭시  갈아탔다고요  정말  아직도 메인  아이폰  들고 다니잖아요   거짓말 해요
# Name: cleaned_comment, dtype: object

# %%
apple_df['noun'] = apple_df['comment'].apply(extract_noun)
apple_df['noun'].head()
# Out:
# 7                                                                                                    가요 아이폰 애플 겔럭시
# 20    업댓 긍정 접근성 가끔 이미지 검색 이미지 저장 거나 스샷 저장 구글 이미지 검색 폴더 이미지 확인 검색 버튼 스윽 어서 검색 결과 확인 프로세스 컴퓨터 거의 요즘 해도 크게 의미 기능 업댓 해
# 69                                                                                                             아이폰
# 71                                                                                                       두목 아이폰 리뷰
# 74                                                                                                 반사 애플 호들갑 홍보 인용
# Name: noun, dtype: object

# %% [markdown]
# ## LLM 키워드

# %%
search_term = {
    "영상 제작": ["화질", "안정감", "음질", "속도", "배터리", "저장 공간", "편집"],
    "사진 촬영": ["해상도", "렌즈", "밝기", "색감", "초점", "필터", "손떨림"],
    "디지털 아트": ["터치", "색상", "부드러움", "성능", "펜", "정밀함", "앱"],
    "음악 & 사운드": ["스피커", "마이크", "노이즈", "베이스", "연결성", "편집", "저장"],
    "쇼핑 & 패션": ["화면", "결제", "색감", "가상", "검색", "리뷰", "추천"],
    "SNS & 커뮤니티": ["카메라", "공유", "필터", "영상", "알림", "댓글", "트렌드"],
    "여행 & 탐방": ["위치", "지도", "배터리", "카메라", "검색", "길찾기", "번역"],
    "모바일 게임": ["반응속도", "화면", "성능", "발열", "몰입감", "조직감", "네트워크"],
    "독서 & 필기": ["화면", "필기감", "배터리", "무게", "관리", "가독성", "저장"],
    "운동 & 건강": ["추적", "심박수", "방수", "연동", "지속력", "센서", "데이터"]
}

# %% [markdown]
# ## 연관어 빈도수

# %%
from sklearn.feature_extraction.text import CountVectorizer

# 연관어 빈도
vectorizer = CountVectorizer(vocabulary=search_term['영상 제작'], ngram_range=(1, 2))
X = vectorizer.fit_transform(apple_df['noun'])

# 각 키워드의 빈도
word_frequencies = X.toarray().sum(axis=0)
frequency_df = pd.DataFrame(word_frequencies, index=vectorizer.get_feature_names_out(), columns=["Frequency"])

print(frequency_df)
# Out:
#        Frequency
# 화질            82
# 안정감            3
# 음질            41
# 속도            68
# 배터리          458
# 저장 공간          6
# 편집            27

# %%
apple_df.loc[apple_df['noun'].str.contains('화질'), 'cleaned_comment']
# Out:
# 751                                                                                                                                                                                                                                                                                                                                                                              아이폰 16 프로 프로 맥스 보니 \n 아직  레드 화질 번인 현상  여전히 개선 되지 않았네요 ㅜㅜ \n 무게   함께   가지  어서 \n 고쳐졌으면 합니다 ㅠㅠ
# 1694                                                                                                                                                                                                                                                   15 프로 맥스 256   쓰고있고  애플스토어 20일  픽업 으로 16 프로 맥스 256   주문 했는데  20일  받는거   중이 였는데 \n  영상  니깐 취소 할까 진지하게 고민 되네  진짜 디자인  똑같고 카메라 빼면 기능  차이는 없다싶이한데  카메라  화질  보면 별로 달라진게 없네  190만원 결재 했는데 15 프맥 팔아도 80만원  쓰는거라  그냥   아낄까 고민
# 3933                                                                                                                                                                                                                                                                                                                                                     아이폰 16 프로  구매 했지만              사방 지만  넣어 줬으면 좋았었는데  배좀 아쉽더라구요  그리고 뭔가  뭔가 화질  애매해요    에서도  처리  15 프로 보다 떨어지는 느낌 입니다
# 4275     새로운 아이폰 프로 결국 변화  준건  카메라  컨트롤 버튼 포함  뿐이긴 하지만  11 프로 부터 매년 새로운 프로  사용 해온 입장 에서 , 카메라  사용 빈도  높은 입장 에서  \n 진짜 많이 궁금하긴 합니다  일반   사용자 입장 에선 현재 15 프로 라면 굳이 16 프로 넘어갈 이유  \n 충분하지 않겠지만  애플 인텔리전스  한국  아직 이고  \n\n 카메라  모두 48 MP  바뀌면서 동영상 촬영   화각 변화  주면 어떨지  기존 15 프로 까지에  화질 변화  생기  툭툭 끊기 기도 하고 , \n 새로운 컨트롤 버튼  얼마나  용도  있을지 몹시 궁금하네요  소프트웨어  으로 어떤 변화  줬을지도  \n 동영상   120  촬영 , 자체 편집 또한 궁금궁금  \n 새로워진 녹음 마이크   성능 역시 완전 궁금  다시 무거워진거는 증말 안타까운  이네   다음 영상 기대 해봅니다
# 4314                                                                                                                                                                                                                                                                                                                                                                                                                    여자   아이폰 사진    하면서 스노우 저화질   화해  찍음 카메라 렌즈    인데
#                                                                                                                                                                                                                                          ...
# 67513                                                                                                                                                                                                                                                                      배줌 에서는 화질 저하  심한것에 비해 막상  배줌 에서는 변화  크지 않아 보이네요  디지털 까지 25 배줌 지원 하니 콘서트  스포츠 직관 에서는 도움  되겠지만  게다가 AR 코팅  고스트 현상   차이  없다니 \n\n 16  예약 했는데 그냥 발열 잡은거랑 배터리 늘어난   만족해야 할듯  12년 쓰고 17   18 프로 넘어갈  같네요
# 67756                                                                                                                                                                                                     AR 관련 보면 거의 대부분  정상 국가  한국  제외  마을 연합체 이지 국가 자격 미달  에선 \n 해당 사항  애플  공개   사기 인데  불구 하고 아무  법적 논란  없죠  \n 여기  하나 배울  있습니다  \n 판매 하는 입장 에선 일정 수준 이상   대놓고 사기 쳐도 되고  \n 사기     에서   해도  사놓고  한다는   \n 화질 변태  불리우는 컬러 스케일   소수 제외   점점 소신 이라는  없어져가는군요  \n   에서 기어 야하는
# 67997                                                                                                                                                                                                                                                                                                                                                                                                         신형 아이폰 나올  마다 화질 선명  색감 좋다고 날리를   언제  구형 아이폰  사진 이쁘게 나온다는 아이러니
# 69126                                                                                                                                                                                                                                                                               14 pro max 에서 16 플러스  변경 하였습니다  결론  사용  만족  합니다  \n 가볍 기도 하고  예뻐서 너무 좋습니다  \n 하지만 카메라 에서 아쉬움  느껴지는  맞는거 같습니다  \n\n   카메라 화질  프로 맥스 부심  내심 있었던거 같아요  후회  10   같습니다   \n\n   너무 너무  쓰고 있어요
# 69774                                                                                                                                                                                                                                                                                                                                                                                                                                                 일반 이랑 프로  카메라 화질  똑같나요
# Name: cleaned_comment, Length: 80, dtype: object

# %%
filtered_comments = apple_df[apple_df['cleaned_comment'].str.contains('|'.join(search_term['영상 제작']))]
print(filtered_comments[['cleaned_comment']])
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                cleaned_comment
# 250      사전예약 마감 2시간 전에 플러스 모델 구매 했는데  끝나고 배송 시작 해서 거의   가까이 걸려 받았어요  물론 인기 색상  재고 부족 인걸 인지  했으나 , 문의 남겨도 1일  입고 된다  배송 시작 안되서 다시 문의 하니 6일  입고 된다   안되서 문의 하니 입고 되었으니 설날 지나고 배송 시작 한다  계속  바꾸기로 시간 끄는 대응    같더라고요   그건 차치  고서 라도   다행히 말씀 하신 문제  GPS  심각하게 느끼는데 출퇴근   교차로 에서 신호 받아서 서있으면  혼자 띵똥띵  거리 면서 유턴  좌회전 우회  알림  계속 울려 대더라고요     대한 해결  으로 일단     대쉬보드   수납 하는   놓으니 감도가  나은지 거기 서는   그러더라고요 GPS   심각합니다  GPS 따라오는게 느려서 속도  실제  70 키로 인데 50 으로 나올   있었구요  아예 뻗어 버려서 안내  중단 되는 경우  있었구요  맨날 출퇴근 하는 길이    과속 카메라 위치  어느 정도 알아서 다행 이지 , 초행길  였으면 몇번 카메라  찍혔을 껍니   속도 부터가  맞아 버리니   무서워서   안키  그냥 육안 으로 바짝 정신차리고 운전 해야   ㅠㅠ
# 379                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              4일 전에 24 플러스  구입 했는데 속도   조선시대 보다  느린데  그럴까
# 435                                                                                                                                                                                                                                                                                                                                                                                                                                    음질 이런거 하나   느낌  버즈  쓰다가 바꿔 야할  되어서 버즈 알아보니 버즈   오픈   이라 불편하고 그래서 프로 샀음 당연히 음질 이나 노캔 기대하면 에어팟 사야하는게 맞긴하지만 그런거 하나   바라고  어차피  느낌  버즈 자동 전환 이랑 착용    만족할려면   밖에 없어서  결론  qc 한번 교환 받았지만 만족함
# 463                                                                                                                                                                                                                                                                                                                                                                                                                                                          추가  용기 입니다  \n  지하철 특히  호선  노캔 모드  실시간 분석 으로  질감   많음 \n  비행기 에서 이륙   지하철  마찬가지  기압 이나 속도 풍압  따라 노캔 실시간   질적 인데 , 적정 고도 올라가서는 괜찮늠 \n  댓글 제보  애플 워치 충전기  자석 으로  붙음
# 473                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           배터리 하고 적응  오디오  어떤가여  프로  하고 비교 해서 많이 적거나 불편한가여
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# 69313                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 비디오 촬영   재생 속도 옵션 에서 프레임율 조절   있는 기능  프로 에만 탑재 되어 있는걸 까요  아니면 일반 모델 에서도 가능한 걸까   궁금합니다아
# 69442                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     13 프맥 쓰다가 16 프맥 으로 바꿨는데  13 프맥 배터리 바꾸고  걸하며 후회  입니다
# 69556                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   12 미니 에서 15  갈아탄지 이제  달좀 넘었는데 솔직히 게임 안하는 사람 입장 에선 성능 차이는  모르겠고 배터리  15   정도 오래 가는거 같네요
# 69774                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  일반 이랑 프로  카메라 화질  똑같나요
# 69859                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         2016 아이폰 se 유저 로서 배터리 빼면 만족도 최상
#
# [577 rows x 1 columns]

# %% [markdown]
# ## KcBERT
# - https://github.com/Beomi/KcBERT
# - https://huggingface.co/beomi/kcbert-base
#
# ## KcELECTRA
# - https://github.com/Beomi/KcELECTRA
#
# ### 모델 fine-tuning
# - sangrimlee/bert-base-multilingual-cased-nsmc (네이버 영화 리뷰)
# - https://github.com/alsgyu/finetunning_huggingface/blob/main/Untitled2.ipynb
#
# ### zero-shot 학습
# - 별도의 라벨링 작업이 필요하지 않지만, 정확도가 높지 않을 가능성 있음
#
# ### few-shot 학습
# - 소량의 라벨링된 데이터를 제공해서 모델이 감성을 학습할 수 있도록 유도

# %%
apple_df['cleaned_comment'].head(10)
# Out:
# 7                                                                                                                                                                                                                        13 pro 에서 넘어갈만  가요 아이폰  부터 지금 까지 애플  써서 겔럭시  처음  보는데
# 20     Ai 업댓  긍정    하나  접근성  쉬워졌다는 겁니다  가끔 이미지 검색 하고 싶을  이미지  저장  거나 스샷  따로 떠서 그걸  저장 해서 구글  들어가서 이미지 검색 으로 들어가서  폴더   이미지  찾아서 확인 누르고 검색    그냥  버튼 하나 누르고 스윽   어서 검색 결과 확인     같은 프로세스  견디기 힘들어서 컴퓨터 로는   써도  에선 거의  썼는데 요즘    쓰고 있습니다    하나  해도   크게 의미 있는 기능 업댓 이라고 생각 해요
# 69                                                                                                                                                                                                                                                          확실히 아이폰  이쁘긴 이쁘네요
# 71                                                                                                                                                                                                                                              두목  아직 아이폰 15 시리즈 리뷰  올라왔습니다
# 74                                                                                                                                                                                                                                   반사 애플   정도  만들었어  호들갑 떨면서 홍보  인용 으로 쓸꺼야
# 100                                                                                                                                                                                                                     아이폰 12 프로 4년 사용 하고 16 프로 왔음  레알 좋다  발열   생겨  뱌터리 오래
# 119                                                                                                                                                                                                                                                 애플  분발 하자  초심 만은 잃지마라 제발
# 122                                                                                                                                                                                                                                             성능  둘째 치고 기본  , 플러스 모델  훨씬 이쁨
# 143                                                                                                                                                                                                            16 프로 맥스  만족  카메라 버튼  쓰든   있으면 알아서 하는거지    있다고 빠진게 없는데 다다익선 이지
# 147                                                                                                                                                                                                                                                      플러스   gen  들어가면 무조건
# Name: cleaned_comment, dtype: object

# %%
# sangrimlee/bert-base-multilingual-cased-nsmc
classifier = pipeline(
    "sentiment-analysis", model="sangrimlee/bert-base-multilingual-cased-nsmc"
)
classifier("흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나.")
# Out:
# [{'label': 'negative', 'score': 0.9642567038536072}]

# %%
classifier('반사 애플   정도  만들었어  호들갑 떨면서 홍보  인용 으로 쓸꺼야 ')
# Out:
# [{'label': 'negative', 'score': 0.9788106679916382}]

# %%
classifier('확실히 아이폰  이쁘긴 이쁘네요')
# Out:
# [{'label': 'negative', 'score': 0.5894982814788818}]

# %%
classifier('성능  둘째 치고 기본  , 플러스 모델  훨씬 이쁨')
# Out:
# [{'label': 'positive', 'score': 0.5247929096221924}]

# %%
classifier('아이폰 12 프로 4년 사용 하고 16 프로 왔음  레알 좋다  발열   생겨  뱌터리 오래')
# Out:
# [{'label': 'positive', 'score': 0.891136109828949}]

# %%
emojis = ''.join([char for char, value in emoji.EMOJI_DATA.items()])
pattern = re.compile(f'[^ .,?!/@$%~％·∼()\x00-\x7Fㄱ-ㅣ가-힣{emojis}]+')
url_pattern = re.compile(
    r'https?:\/\/(www\.)?[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)')

# 특수 문자, 이모지, URL, 반복된 글자 등을 처리
def clean(x): 
    x = pattern.sub(' ', x)
    x = emoji.replace_emoji(x, replace='') 
    x = url_pattern.sub('', x)
    x = x.strip()
    x = repeat_normalize(x, num_repeats=2)
    return x

# %%
apple_df['clean_text'] = apple_df['comment'].apply(clean)
print(apple_df['comment'].tail())
print(" ")
print(apple_df['clean_text'].tail())
# Out:
# 73114                                                                                                                                                       1년 뒤……..\n\n\n\n???: “아이폰 17보다 16을 추천하는 이유!”
# 73139                                                                                                                                                             아이폰 시리즌 베챔 없는거 치곤  발열 저정도면 나쁘지 않은거 같은데
# 73142                                                                                                                                                                                     걍 아이폰 디자인인데 ㅋㅋ
# 73158                                                                                                                                                                                  S25플러스 블랙은 왜 뺀거야?
# 73168    11프로 사용자인데 120의 주사율을 느껴본 적이 없어서 굳이 16프로 대신 일반 16이나 16플러스로 갈까합니다. 그런데 16도 11프로보다 화면이 좀 크더군요. (5.8":6.1"). 차라리 핸드폰 용량을 키우는 게 낫겠다 싶고 원래 16프로 기변 대신  세이브된 금액(?)으로 아이패드 미니5를 미니6으로 바꾸는데 보탤까 생각 중입니다.
# Name: comment, dtype: object
#
# 73114                                                                                                                                                                1년 뒤 .. ???: 아이폰 17보다 16을 추천하는 이유!
# 73139                                                                                                                                                             아이폰 시리즌 베챔 없는거 치곤 발열 저정도면 나쁘지 않은거 같은데
# 73142                                                                                                                                                                                    걍 아이폰 디자인인데 ㅋㅋ
# 73158                                                                                                                                                                                 S25플러스 블랙은 왜 뺀거야?
# 73168    11프로 사용자인데 120의 주사율을 느껴본 적이 없어서 굳이 16프로 대신 일반 16이나 16플러스로 갈까합니다. 그런데 16도 11프로보다 화면이 좀 크더군요. (5.8":6.1"). 차라리 핸드폰 용량을 키우는 게 낫겠다 싶고 원래 16프로 기변 대신 세이브된 금액(?)으로 아이패드 미니5를 미니6으로 바꾸는데 보탤까 생각 중입니다.
# Name: clean_text, dtype: object

# %%
# nlp04/korean_sentiment_analysis_kcelectra
from transformers import AutoTokenizer, AutoModelForSequenceClassification

model_name = "nlp04/korean_sentiment_analysis_kcelectra"
classifier = pipeline("text-classification", model=model_name)

texts = [
    "이 영화 정말 재미있었어요!",
    "서비스가 너무 나빠서 다시는 안 갈 것 같아요.",
    "아이폰 디자인은 평범해요."
]

for text in texts:
    result = classifier(text)
    print(f"텍스트: {text}")
    print(f"감성: {result[0]['label']}, 점수: {result[0]['score']:.4f}")
    print()
# Out:
# 텍스트: 이 영화 정말 재미있었어요!
# 감성: 기쁨(행복한), 점수: 0.5357
#
# 텍스트: 서비스가 너무 나빠서 다시는 안 갈 것 같아요.
# 감성: 짜증남, 점수: 0.9178
#
# 텍스트: 아이폰 디자인은 평범해요.
# 감성: 슬픔(우울한), 점수: 0.6849

# %%
id2label = model.config.id2label
print("감성 클래스 개수:", len(id2label))
print("감성 클래스 목록:", id2label)
# Out:
# 감성 클래스 개수: 11
# 감성 클래스 목록: {0: '기쁨(행복한)', 1: '고마운', 2: '설레는(기대하는)', 3: '사랑하는', 4: '즐거운(신나는)', 5: '일상적인', 6: '생각이 많은', 7: '슬픔(우울한)', 8: '힘듦(지침)', 9: '짜증남', 10: '걱정스러운(불안한)'}

# %%
# KcELECTRA 모델
model_name = "beomi/KcELECTRA-base-v2022"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name, num_labels=3)

# %%
# # KcBERT 모델
# model_name = "beomi/kcbert-base"

# # 토크나이저
# tokenizer = AutoTokenizer.from_pretrained(model_name)

# # 모델
# model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)

# # 입력
# texts = filtered_comments.cleaned_comment.values.tolist()
# inputs = tokenizer(texts, padding=True, truncation=True, return_tensors="pt")

# # 예측
# with torch.no_grad():
#     outputs = model(**inputs)
#     predictions = torch.softmax(outputs.logits, dim=1)

# # 결과
# for text, pred in zip(texts, predictions):
#     sentiment = "긍정" if pred[1] > pred[0] else "부정"
#     print(f"텍스트: {text}")
#     print(f"감성: {sentiment} (긍정 확률: {pred[1].item():.2f})")
#     print()

# %% [markdown]
# ## TF-IDF

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(apple_df['cleaned_noun'])
tfidf_apple_df = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out())
print(tfidf_apple_df)

# %%
tfidf_apple_df.mean().sort_values(ascending=False).head(100)

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(apple_df['cleaned_noun'])
tfidf_samsung_df = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out())
print(tfidf_samsung_df)

# %%
tfidf_samsung_df.mean().sort_values(ascending=False).head(100)

# %% [markdown]
# ## BERTopic
# - 개념 설명 : https://wikidocs.net/162079
# - 알고리즘 비교 논문
#   - https://accesson.kr/kslis/assets/pdf/38798/journal-58-1-5.pdf
#   - https://journal.comm.or.kr/xml/37619/37619.pdf
# - 참고 블로그 : https://mz-moonzoo.tistory.com/24
#
# ### 모델 파라미터
# - embedding_model : 텍스트를 고차원 벡터로 변환
# - vectorizer_model : 텍스트의 단어 빈도를 기반으로 벡터화
# - top_n_words : 상위 n개 단어 추출
# - min_topic_size : 각 주제의 최소 크기(클러스터 크기)
# - umap_model : 차원 축소
# - hdbscan_model : 밀도 기반 클러스터링
# - verbose=True : 로그 출력

# %%
umap_model = UMAP(n_neighbors=15,
                  min_dist=0.1,
                  n_components=5,
                  random_state=42,
                  metric='cosine')
hdbscan_model = hdbscan.HDBSCAN(min_cluster_size=10,
                                metric='euclidean',
                                cluster_selection_method='eom',
                                prediction_data=True)
model = BERTopic(embedding_model="sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens",
                 vectorizer_model=None,
                 top_n_words=15,
                 min_topic_size=10,
                 umap_model=umap_model,
                 hdbscan_model=hdbscan_model,
                 verbose=True)

# %%
topics, probs = model.fit_transform(apple_df['cleaned_noun'])
model.get_topic_info()

# %%
for i in range(len(set(topics))):
    print(f"Topic {i}: {model.get_topic(i)}")

# %%
# 토픽별 분포 시각화
model.visualize_topics()
